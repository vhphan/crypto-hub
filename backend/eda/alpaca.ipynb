# %%
import os

from alpaca.data.historical import CryptoHistoricalDataClient
from alpaca.data.requests import CryptoBarsRequest
from alpaca.data.timeframe import TimeFrame

# %%
client = CryptoHistoricalDataClient()

# %%
client.list_crypto_assets()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 client.list_crypto_assets()
#
# AttributeError: 'CryptoHistoricalDataClient' object has no attribute 'list_crypto_assets'

# %%
request_params = CryptoBarsRequest(
                        symbol_or_symbols=["BTC/USD", "ETH/USD"],
                        timeframe=TimeFrame.Day,
                        start="2024-01-01"
                 )

bars = client.get_crypto_bars(request_params)

# %%
bars

# %%
request_params = CryptoBarsRequest(
                        symbol_or_symbols=["BTC/USD", "ETH/USD"],
                        timeframe=TimeFrame.Minute,
                        start="2024-06-15",
                        limit=1000
                 )

bars = client.get_crypto_bars(request_params)

# %%
bars

# %%
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
import os
os.environ
# Out:
# environ{'PATH': '/home/vhphan/PycharmProjects/crypto-hub/backend/.venv/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/usr/games:/usr/local/games:/usr/lib/wsl/lib',
#         'TERM': 'xterm-color',
#         'LANG': 'en_US.UTF-8',
#         'PS1': '(.venv) ',
#         'DISPLAY': 'localhost:10.0',
#         'LOGNAME': 'vhphan',
#         'PWD': '/home/vhphan/PycharmProjects/crypto-hub',
#         '_': '/opt/pycharm-2024.1.1/bin/pycharm.sh',
#         'LANGUAGE': '',
#         'PYTHONPATH': '/home/vhphan/PycharmProjects/crypto-hub',
#         'SHELL': '/bin/bash',
#         'WSL_INTEROP': '/run/WSL/21741_interop',
#         'WSL_DISTRO_NAME': 'Ubuntu',
#         'HOSTTYPE': 'x86_64',
#         'SSH_TTY': '/dev/pts/2',
#         'SSH_CLIENT': '127.0.0.1 35004 22004',
#         'USER': 'vhphan',
#         'NAME': 'E-5CG2090425',
#         'LIBGL_ALWAYS_INDIRECT': '1',
#         'VIRTUAL_ENV': '/home/vhphan/PycharmProjects/crypto-hub/backend/.venv',
#         'SSH_CONNECTION': '127.0.0.1 35004 127.0.0.1 22004',
#         'LC_ALL': 'en_US.UTF-8',
#         'WSLENV': '',
#         'HOME': '/home/vhphan',
#         'SHLVL': '1',
#         'JPY_SESSION_NAME': 'backend/eda/play.ipynb',
#         'JPY_PARENT_PID': '24475',
#         'PYDEVD_USE_FRAME_EVAL': 'NO',
#         'CLICOLOR': '1',
#         'FORCE_COLOR': '1',
#         'CLICOLOR_FORCE': '1',
#         'PAGER': 'cat',
#         'GIT_PAGER': 'cat',
#         'MPLBACKEND': 'module://matplotlib_inline.backend_inline',
#         'PORT': '3311',
#         'ALPACA_PAPER_API_KEY': 'PKQL4627RT7D7H5G0B6S',
#         'ALPACA_PAPER_SECRET': 'c14yN13ceUJB55gM90bdYRLGKsra6NtGHVMMEpaR'}

# %%
from alpaca.trading.client import TradingClient
from alpaca.trading.requests import GetAssetsRequest
from alpaca.trading.enums import AssetClass

trading_client = TradingClient(os.environ['ALPACA_PAPER_API_KEY'], os.environ['ALPACA_PAPER_SECRET'])

# search for crypto assets
search_params = GetAssetsRequest(asset_class=AssetClass.CRYPTO)

assets = trading_client.get_all_assets(search_params)

# %%
assets
# Out:
# [{   'asset_class': <AssetClass.CRYPTO: 'crypto'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.CRYPTO: 'CRYPTO'>,
#      'fractionable': True,
#      'id': UUID('0425de77-90d3-4ac9-b914-73423b4e42b8'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': 2.880441514,
#      'min_trade_increment': 1e-09,
#      'name': 'Curve / US Dollar',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'CRV/USD',
#      'tradable': True},
#  {   'asset_class': <AssetClass.CRYPTO: 'crypto'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.CRYPTO: 'CRYPTO'>,
#      'fractionable': True,
#      'id': UUID('dedf4e7b-3d95-4393-ab91-1181f0ed702e'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': 3.134992789,
#      'min_trade_increment': 1e-09,
#      'name': 'Curve / USD Coin',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'CRV/USDC',
#      'tradable': True},
#  {   'asset_class': <AssetClass.CRYPTO: 'crypto'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.CRYPTO: 'CRYPTO'>,
#      'fractionable': True,
#      'id': UUID('ff2ec3b7-b581-4a5f-8f75-a98a68ed8332'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': 8.176614881,
#      'min_trade_increment': 1e-09,
#      'name': 'Dogecoin / USD Coin',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'DOGE/USDC',
#      'tradable': True},
#  {   'asset_class': <AssetClass.CRYPTO: 'crypto'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.CRYPTO: 'CRYPTO'>,
#      'fractionable': True,
#      'id': UUID('38f8a0a4-399c-4f5a-8c0d-7435faef70d1'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': 1.001301692,
#      'min_trade_increment': 1e-09,
#      'name': 'USDC/USD pair',
#      'price_increment': 0.0001,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'USDC/USD',
#      'tradable': True},
#  {   'asset_class': <AssetClass.CRYPTO: 'crypto'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.CRYPTO: 'CRYPTO'>,
#      'fractionable': True,
#      'id': UUID('8588af33-3a8e-4a09-bb6c-ba4226dc7aff'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': 0.012623616,
#      'min_trade_increment': 1e-09,
#      'name': 'Aave / US Dollar',
#      'price_increment': 0.01,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'AAVE/USD',
#      'tradable': True},
#  {   'asset_class': <AssetClass.CRYPTO: 'crypto'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.CRYPTO: 'CRYPTO'>,
#      'fractionable': True,
#      'id': UUID('73adad68-0e0e-45cb-9bcc-66135068cb4d'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': 0.012396181,
#      'min_trade_increment': 1e-09,
#      'name': 'Aave / USD Coin',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'AAVE/USDC',
#      'tradable': True},
#  {   'asset_class': <AssetClass.CRYPTO: 'crypto'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.CRYPTO: 'CRYPTO'>,
#      'fractionable': True,
#      'id': UUID('dfb6d1da-427c-42b6-864d-f227af29e2e9'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': 0.011790923,
#      'min_trade_increment': 1e-09,
#      'name': 'Aave / USD Tether',
#      'price_increment': 0.01,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'AAVE/USDT',
#      'tradable': True},
#  {   'asset_class': <AssetClass.CRYPTO: 'crypto'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.CRYPTO: 'CRYPTO'>,
#      'fractionable': True,
#      'id': UUID('0515189d-1933-4a94-89ce-4e9a24356d58'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': 0.037195462,
#      'min_trade_increment': 1e-09,
#      'name': 'Avalanche / US Dollar',
#      'price_increment': 0.0005,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'AVAX/USD',
#      'tradable': True},
#  {   'asset_class': <AssetClass.CRYPTO: 'crypto'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.CRYPTO: 'CRYPTO'>,
#      'fractionable': True,
#      'id': UUID('b7b73bc2-e3bc-4b37-8fcf-4eac793027ef'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': 0.037605294,
#      'min_trade_increment': 1e-09,
#      'name': 'Avalanche / USD Coin',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'AVAX/USDC',
#      'tradable': True},
#  {   'asset_class': <AssetClass.CRYPTO: 'crypto'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.CRYPTO: 'CRYPTO'>,
#      'fractionable': True,
#      'id': UUID('da3ee262-cfed-4fef-8e63-13f87911704d'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': 0.020445716,
#      'min_trade_increment': 1e-09,
#      'name': 'Avalanche / USD Tether',
#      'price_increment': 0.0005,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'AVAX/USDT',
#      'tradable': True},
#  {   'asset_class': <AssetClass.CRYPTO: 'crypto'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.CRYPTO: 'CRYPTO'>,
#      'fractionable': True,
#      'id': UUID('50960a81-1ec0-45b8-89dc-d6d3ab92f894'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': 5.500156754,
#      'min_trade_increment': 1e-09,
#      'name': 'Basic Attention Token / US Dollar',
#      'price_increment': 2.5e-05,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'BAT/USD',
#      'tradable': True},
#  {   'asset_class': <AssetClass.CRYPTO: 'crypto'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.CRYPTO: 'CRYPTO'>,
#      'fractionable': True,
#      'id': UUID('72d88488-20b6-4fc2-a670-a8b706c86c4f'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': 5.543114343,
#      'min_trade_increment': 1e-09,
#      'name': 'Basic Attention Token / USD Coin',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'BAT/USDC',
#      'tradable': True},
#  {   'asset_class': <AssetClass.CRYPTO: 'crypto'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.CRYPTO: 'CRYPTO'>,
#      'fractionable': True,
#      'id': UUID('c9b6f16b-e88d-439f-bb0b-acecccab3d10'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': 235.21663452,
#      'min_trade_increment': 1e-09,
#      'name': 'Bitcoin Cash / Bitcoin ',
#      'price_increment': 1e-06,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'BCH/BTC',
#      'tradable': True},
#  {   'asset_class': <AssetClass.CRYPTO: 'crypto'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.CRYPTO: 'CRYPTO'>,
#      'fractionable': True,
#      'id': UUID('f0a05db3-5c93-4524-8a32-2f2b8d4f12fc'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': 0.002570429,
#      'min_trade_increment': 1e-09,
#      'name': 'Bitcoin Cash / US Dollar',
#      'price_increment': 0.025,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'BCH/USD',
#      'tradable': True},
#  {   'asset_class': <AssetClass.CRYPTO: 'crypto'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.CRYPTO: 'CRYPTO'>,
#      'fractionable': True,
#      'id': UUID('9a3baaff-11b0-4428-a63c-f6e3340694e1'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': 0.002587971,
#      'min_trade_increment': 1e-09,
#      'name': 'Bitcoin Cash / USD Coin',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'BCH/USDC',
#      'tradable': True},
#  {   'asset_class': <AssetClass.CRYPTO: 'crypto'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.CRYPTO: 'CRYPTO'>,
#      'fractionable': True,
#      'id': UUID('56272c8a-e888-4549-aa86-1779996f8bb2'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': 0.004233341,
#      'min_trade_increment': 1e-09,
#      'name': 'Bitcoin Cash / USD Tether',
#      'price_increment': 0.025,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'BCH/USDT',
#      'tradable': True},
#  {   'asset_class': <AssetClass.CRYPTO: 'crypto'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.CRYPTO: 'CRYPTO'>,
#      'fractionable': True,
#      'id': UUID('276e2673-764b-4ab6-a611-caf665ca6340'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': 1.5356e-05,
#      'min_trade_increment': 1e-09,
#      'name': 'Bitcoin  / US Dollar',
#      'price_increment': 1.0,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'BTC/USD',
#      'tradable': True},
#  {   'asset_class': <AssetClass.CRYPTO: 'crypto'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.CRYPTO: 'CRYPTO'>,
#      'fractionable': True,
#      'id': UUID('e88ec72e-9707-4aac-8e33-86291e5f2b4a'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': 1.4249e-05,
#      'min_trade_increment': 1e-09,
#      'name': 'Bitcoin / USD Coin',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'BTC/USDC',
#      'tradable': True},
#  {   'asset_class': <AssetClass.CRYPTO: 'crypto'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.CRYPTO: 'CRYPTO'>,
#      'fractionable': True,
#      'id': UUID('c150e086-1e75-44e6-9c2c-093bb1e93139'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': 1.5035e-05,
#      'min_trade_increment': 1e-09,
#      'name': 'Bitcoin / USD Tether',
#      'price_increment': 1.0,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'BTC/USDT',
#      'tradable': True},
#  {   'asset_class': <AssetClass.CRYPTO: 'crypto'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.CRYPTO: 'CRYPTO'>,
#      'fractionable': True,
#      'id': UUID('03e005f7-4bfc-4616-b1b0-225dd64074fa'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': 8.061765636,
#      'min_trade_increment': 1e-09,
#      'name': 'Dogecoin / US Dollar',
#      'price_increment': 5e-07,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'DOGE/USD',
#      'tradable': True},
#  {   'asset_class': <AssetClass.CRYPTO: 'crypto'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.CRYPTO: 'CRYPTO'>,
#      'fractionable': True,
#      'id': UUID('7b4c3c70-b54b-4328-85fb-c24bdb45ef45'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': 11.750743234,
#      'min_trade_increment': 1e-09,
#      'name': 'Dogecoin / USD Tether',
#      'price_increment': 5e-07,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'DOGE/USDT',
#      'tradable': True},
#  {   'asset_class': <AssetClass.CRYPTO: 'crypto'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.CRYPTO: 'CRYPTO'>,
#      'fractionable': True,
#      'id': UUID('764fb9f4-14a1-4c93-bcf9-6a460029143d'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': 0.17175166,
#      'min_trade_increment': 1e-09,
#      'name': 'Polkadot / US Dollar',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'DOT/USD',
#      'tradable': True},
#  {   'asset_class': <AssetClass.CRYPTO: 'crypto'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.CRYPTO: 'CRYPTO'>,
#      'fractionable': True,
#      'id': UUID('ec294909-7421-4bcd-b991-e8de5a67ecab'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': 0.173731758,
#      'min_trade_increment': 1e-09,
#      'name': 'Polkadot / USD Coin',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'DOT/USDC',
#      'tradable': True},
#  {   'asset_class': <AssetClass.CRYPTO: 'crypto'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.CRYPTO: 'CRYPTO'>,
#      'fractionable': True,
#      'id': UUID('47d0ce51-247b-483b-908a-b62dfbcb957e'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': 17.531864163,
#      'min_trade_increment': 1e-09,
#      'name': 'Ethereum / Bitcoin ',
#      'price_increment': 2.5e-06,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'ETH/BTC',
#      'tradable': True},
#  {   'asset_class': <AssetClass.CRYPTO: 'crypto'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.CRYPTO: 'CRYPTO'>,
#      'fractionable': True,
#      'id': UUID('a1733398-6acc-4e92-af24-0d0667f78713'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': 0.000283169,
#      'min_trade_increment': 1e-09,
#      'name': 'Ethereum / US Dollar',
#      'price_increment': 0.1,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'ETH/USD',
#      'tradable': True},
#  {   'asset_class': <AssetClass.CRYPTO: 'crypto'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.CRYPTO: 'CRYPTO'>,
#      'fractionable': True,
#      'id': UUID('30c8659a-9a9b-42c8-a093-2673ce98f875'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': 0.000288272,
#      'min_trade_increment': 1e-09,
#      'name': 'Ethereum / USD Coin',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'ETH/USDC',
#      'tradable': True},
#  {   'asset_class': <AssetClass.CRYPTO: 'crypto'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.CRYPTO: 'CRYPTO'>,
#      'fractionable': True,
#      'id': UUID('08b74a3d-9046-4e8f-abbc-8af9f4e5cad7'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': 0.000260002,
#      'min_trade_increment': 1e-09,
#      'name': 'Ethereum / USD Tether',
#      'price_increment': 0.1,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'ETH/USDT',
#      'tradable': True},
#  {   'asset_class': <AssetClass.CRYPTO: 'crypto'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.CRYPTO: 'CRYPTO'>,
#      'fractionable': True,
#      'id': UUID('3e242d92-02c9-42d8-a2a1-e04f8b2f8860'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': 4.849190185,
#      'min_trade_increment': 1e-09,
#      'name': 'The Graph / US Dollar',
#      'price_increment': 5e-05,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'GRT/USD',
#      'tradable': True},
#  {   'asset_class': <AssetClass.CRYPTO: 'crypto'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.CRYPTO: 'CRYPTO'>,
#      'fractionable': True,
#      'id': UUID('b1365689-2b1b-4b84-a263-67d5c622728d'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': 4.958792434,
#      'min_trade_increment': 1e-09,
#      'name': 'The Graph / USD Coin',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'GRT/USDC',
#      'tradable': True},
#  {   'asset_class': <AssetClass.CRYPTO: 'crypto'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.CRYPTO: 'CRYPTO'>,
#      'fractionable': True,
#      'id': UUID('fa9b6855-0ed2-44d5-af2a-4aad84e77307'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': 4835.589941972,
#      'min_trade_increment': 1e-09,
#      'name': 'Chainlink / Bitcoin ',
#      'price_increment': 5e-08,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'LINK/BTC',
#      'tradable': True},
#  {   'asset_class': <AssetClass.CRYPTO: 'crypto'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.CRYPTO: 'CRYPTO'>,
#      'fractionable': True,
#      'id': UUID('faf30512-0c0d-4ff8-a7a0-169c747d1e9c'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': 0.072516316,
#      'min_trade_increment': 1e-09,
#      'name': 'Chainlink / US Dollar',
#      'price_increment': 0.0005,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'LINK/USD',
#      'tradable': True},
#  {   'asset_class': <AssetClass.CRYPTO: 'crypto'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.CRYPTO: 'CRYPTO'>,
#      'fractionable': True,
#      'id': UUID('e8e88d77-460f-466b-a076-88b298bed939'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': 0.072397665,
#      'min_trade_increment': 1e-09,
#      'name': 'Chainlink / USD Coin',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'LINK/USDC',
#      'tradable': True},
#  {   'asset_class': <AssetClass.CRYPTO: 'crypto'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.CRYPTO: 'CRYPTO'>,
#      'fractionable': True,
#      'id': UUID('b8c60aea-6346-42d9-a664-4a49405ddb30'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': 0.063457413,
#      'min_trade_increment': 1e-09,
#      'name': 'Chainlink / USD Tether',
#      'price_increment': 0.0005,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'LINK/USDT',
#      'tradable': True},
#  {   'asset_class': <AssetClass.CRYPTO: 'crypto'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.CRYPTO: 'CRYPTO'>,
#      'fractionable': True,
#      'id': UUID('a9897852-02eb-444a-80fa-ff2a2d329643'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': 113.170948112,
#      'min_trade_increment': 1e-09,
#      'name': 'Litecoin / Bitcoin ',
#      'price_increment': 2.5e-07,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'LTC/BTC',
#      'tradable': True},
#  {   'asset_class': <AssetClass.CRYPTO: 'crypto'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.CRYPTO: 'CRYPTO'>,
#      'fractionable': True,
#      'id': UUID('19c466e7-e8f7-43e0-a8c5-f17ec9f5de8d'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': 0.013778279,
#      'min_trade_increment': 1e-09,
#      'name': 'Litecoin / US Dollar',
#      'price_increment': 0.005,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'LTC/USD',
#      'tradable': True},
#  {   'asset_class': <AssetClass.CRYPTO: 'crypto'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.CRYPTO: 'CRYPTO'>,
#      'fractionable': True,
#      'id': UUID('aa89f7ea-b30a-4ea4-a34c-1f58e7fef13c'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': 0.013800717,
#      'min_trade_increment': 1e-09,
#      'name': 'Litecoin / USD Coin',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'LTC/USDC',
#      'tradable': True},
#  {   'asset_class': <AssetClass.CRYPTO: 'crypto'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.CRYPTO: 'CRYPTO'>,
#      'fractionable': True,
#      'id': UUID('77c6f47f-0939-4b23-b41e-47b4469c4bc8'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': 0.014402995,
#      'min_trade_increment': 1e-09,
#      'name': 'Litecoin / USD Tether',
#      'price_increment': 0.005,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'LTC/USDT',
#      'tradable': True},
#  {   'asset_class': <AssetClass.CRYPTO: 'crypto'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.CRYPTO: 'CRYPTO'>,
#      'fractionable': True,
#      'id': UUID('90a83e2d-e574-404b-9344-74130736b71c'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': 0.000450259,
#      'min_trade_increment': 1e-09,
#      'name': 'Maker / US Dollar',
#      'price_increment': 0.5,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'MKR/USD',
#      'tradable': True},
#  {   'asset_class': <AssetClass.CRYPTO: 'crypto'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.CRYPTO: 'CRYPTO'>,
#      'fractionable': True,
#      'id': UUID('d31cd0b3-852c-435b-a1ea-ace997ce550a'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': 0.000449519,
#      'min_trade_increment': 1e-09,
#      'name': 'Maker / USD Coin',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'MKR/USDC',
#      'tradable': True},
#  {   'asset_class': <AssetClass.CRYPTO: 'crypto'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.CRYPTO: 'CRYPTO'>,
#      'fractionable': True,
#      'id': UUID('80d871ac-7a59-48b1-b71d-760d5a6876c6'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': 56593.095642331,
#      'min_trade_increment': 1e-09,
#      'name': 'Shiba Inu / US Dollar',
#      'price_increment': 1e-08,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'SHIB/USD',
#      'tradable': True},
#  {   'asset_class': <AssetClass.CRYPTO: 'crypto'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.CRYPTO: 'CRYPTO'>,
#      'fractionable': True,
#      'id': UUID('da533b7e-5b35-45ef-8ba8-4dd5d44978b8'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': 54794.520547945,
#      'min_trade_increment': 1e-09,
#      'name': 'Shiba Inu / USD Coin',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'SHIB/USDC',
#      'tradable': True},
#  {   'asset_class': <AssetClass.CRYPTO: 'crypto'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.CRYPTO: 'CRYPTO'>,
#      'fractionable': False,
#      'id': UUID('bce5b2e7-0678-4b81-9607-4a997471fc92'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': 35248.501938667,
#      'min_trade_increment': 1e-09,
#      'name': 'Shib USD Tether',
#      'price_increment': 1e-08,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'SHIB/USDT',
#      'tradable': True},
#  {   'asset_class': <AssetClass.CRYPTO: 'crypto'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.CRYPTO: 'CRYPTO'>,
#      'fractionable': True,
#      'id': UUID('ce414735-ba65-43c8-be76-7cb78ed2413d'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': 1.273398701,
#      'min_trade_increment': 1e-09,
#      'name': 'SushiSwap / US Dollar',
#      'price_increment': 0.0001,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'SUSHI/USD',
#      'tradable': True},
#  {   'asset_class': <AssetClass.CRYPTO: 'crypto'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.CRYPTO: 'CRYPTO'>,
#      'fractionable': True,
#      'id': UUID('34bfd447-3a3f-4d03-b3f7-3bbbfd57c6ab'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': 1.237450703,
#      'min_trade_increment': 1e-09,
#      'name': 'SushiSwap / USD Coin',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'SUSHI/USDC',
#      'tradable': True},
#  {   'asset_class': <AssetClass.CRYPTO: 'crypto'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.CRYPTO: 'CRYPTO'>,
#      'fractionable': True,
#      'id': UUID('020f162d-9d1f-4ee2-8476-a0c4f592615e'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': 0.994846694,
#      'min_trade_increment': 1e-09,
#      'name': 'SushiSwap / USD Tether',
#      'price_increment': 0.0001,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'SUSHI/USDT',
#      'tradable': True},
#  {   'asset_class': <AssetClass.CRYPTO: 'crypto'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.CRYPTO: 'CRYPTO'>,
#      'fractionable': True,
#      'id': UUID('35b8e824-e0d2-4546-a9ec-02a8a301139f'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': 5787.037037037,
#      'min_trade_increment': 1e-09,
#      'name': 'Uniswap / Bitcoin',
#      'price_increment': 5e-08,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'UNI/BTC',
#      'tradable': True},
#  {   'asset_class': <AssetClass.CRYPTO: 'crypto'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.CRYPTO: 'CRYPTO'>,
#      'fractionable': True,
#      'id': UUID('39d2df3b-4273-46a9-956d-c23634be1e38'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': 0.092631188,
#      'min_trade_increment': 1e-09,
#      'name': 'Uniswap / US Dollar',
#      'price_increment': 0.001,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'UNI/USD',
#      'tradable': True},
#  {   'asset_class': <AssetClass.CRYPTO: 'crypto'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.CRYPTO: 'CRYPTO'>,
#      'fractionable': True,
#      'id': UUID('84a8d30e-b945-4a76-b163-979dd14aa5e2'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': 0.103859415,
#      'min_trade_increment': 1e-09,
#      'name': 'Uniswap / USD Coin',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'UNI/USDC',
#      'tradable': True},
#  {   'asset_class': <AssetClass.CRYPTO: 'crypto'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.CRYPTO: 'CRYPTO'>,
#      'fractionable': True,
#      'id': UUID('70ac93c5-7d32-4545-9f58-b03972f185a1'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': 0.159349852,
#      'min_trade_increment': 1e-09,
#      'name': 'Uniswap / USD Tether',
#      'price_increment': 0.001,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'UNI/USDT',
#      'tradable': True},
#  {   'asset_class': <AssetClass.CRYPTO: 'crypto'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.CRYPTO: 'CRYPTO'>,
#      'fractionable': True,
#      'id': UUID('541b0d67-c2c7-4135-ac31-ff2aa6c0dd71'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': 1.001401962,
#      'min_trade_increment': 1e-09,
#      'name': 'USD Tether / US Dollar',
#      'price_increment': 0.0001,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'USDT/USD',
#      'tradable': True},
#  {   'asset_class': <AssetClass.CRYPTO: 'crypto'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.CRYPTO: 'CRYPTO'>,
#      'fractionable': True,
#      'id': UUID('684a2cad-85c3-4e09-ac9d-b8893dd1e02f'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': 1.002024088,
#      'min_trade_increment': 1e-09,
#      'name': 'USD Tether / USD Coin',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'USDT/USDC',
#      'tradable': True},
#  {   'asset_class': <AssetClass.CRYPTO: 'crypto'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.CRYPTO: 'CRYPTO'>,
#      'fractionable': True,
#      'id': UUID('6a521dc8-c56b-4096-bb84-66e0db2d155d'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': 1.337583281,
#      'min_trade_increment': 1e-09,
#      'name': 'Tezos / US Dollar',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'XTZ/USD',
#      'tradable': True},
#  {   'asset_class': <AssetClass.CRYPTO: 'crypto'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.CRYPTO: 'CRYPTO'>,
#      'fractionable': True,
#      'id': UUID('83932f5b-533e-4c69-876a-a120b0ae01c1'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': 1.352471709,
#      'min_trade_increment': 1e-09,
#      'name': 'Tezos / USD Coin',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'XTZ/USDC',
#      'tradable': True},
#  {   'asset_class': <AssetClass.CRYPTO: 'crypto'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.CRYPTO: 'CRYPTO'>,
#      'fractionable': True,
#      'id': UUID('9e853ba9-1eea-4226-8a39-c9995420e2c9'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': 0.000160581,
#      'min_trade_increment': 1e-09,
#      'name': 'Yearn Finance / US Dollar',
#      'price_increment': 5.0,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'YFI/USD',
#      'tradable': True},
#  {   'asset_class': <AssetClass.CRYPTO: 'crypto'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.CRYPTO: 'CRYPTO'>,
#      'fractionable': True,
#      'id': UUID('94c9594d-610a-4235-9298-d9a552461a39'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': 0.00017439,
#      'min_trade_increment': 1e-09,
#      'name': 'Yearn Finance / USD Coin',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'YFI/USDC',
#      'tradable': True},
#  {   'asset_class': <AssetClass.CRYPTO: 'crypto'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.CRYPTO: 'CRYPTO'>,
#      'fractionable': True,
#      'id': UUID('82bc6fef-5fb6-48b5-a42e-16a5cbf86c60'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': 0.000140181,
#      'min_trade_increment': 1e-09,
#      'name': 'Yearn Finance / USD Tether',
#      'price_increment': 5.0,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'YFI/USDT',
#      'tradable': True}]
